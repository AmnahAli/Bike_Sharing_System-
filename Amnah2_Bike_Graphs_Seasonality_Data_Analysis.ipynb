# %% [markdown]
# # #Note there others Graphs ON R for Boxplot analysis

# %% [markdown]
# #Load Train and Test Sets

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib

#First let's open Bicycle train.csv and take a look at it. 
df_train = pd.read_csv('train.csv',parse_dates=["datetime"],header = 0)
df_test = pd.read_csv('test.csv',parse_dates=["datetime"],header = 0)

# %% [markdown]
# #Feature engenieering

# %%
#To convert a Series or list-like object of date-like objects e.g. strings I can use the to_datetime function. Here I can use pd.DatetimeIndex to extract month, day and hour out of datetime column. For the day column I would like to show it as day of week, where Monday = 0 and Sunday = 6
df_train['month'] = pd.DatetimeIndex(df_train.datetime).month
df_train['day'] = pd.DatetimeIndex(df_train.datetime).dayofweek
#df_train['days'] = pd.DatetimeIndex(df_train.datetime).date
df_train['hour'] = pd.DatetimeIndex(df_train.datetime).hour
df_train['year'] = pd.DatetimeIndex(df_train.datetime).year


df_train['weekday'] = pd.DatetimeIndex(df_train.datetime).week
df_train['Saturday']=0
df_train['Sunday']=0
df_train.Saturday[df_train.day==5]=1
df_train.Sunday[df_train.day==6]=1
#g = df_train.groupby(pd.DatetimeIndex(df_train['day']).normalize())
#g = df_train.groupby(df_train['day'].normalize())

# %% [markdown]
# #Plot data for analysis

# %%
'''
g = df_train.groupby('day')
g['counts'].sum().plot()

plt.figure();
g = df_train.groupby('Saturday')
g['counts'].sum().plot()

plt.figure();
g = df_train.groupby('Sunday')
g['counts'].sum().plot()
'''

train_time = pd.TimeSeries(df_train['registered'].values,index=df_train.datetime.values)
train_time = train_time.sort_index()
train_H = train_time.resample('H',how='sum',fill_method='backfill')
train_D = train_time.resample('D',how='sum',fill_method='backfill')
train_M = train_time.resample('M',how='sum',fill_method='backfill')


plt.figure();
train_H[df_train.datetime.values].plot()
#plt.plot(train_H)
plt.xlabel("Period 2011-2012");   #Period 2011-2012
plt.ylabel("Count")
#plt.title("Average Daily Rental Counts by Month");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/Average_Daily_Rental_registered_by_Hour.png")
plt.show()



#df_train['counts'].boxplot(by='g')
 #bp = df_box.boxplot(by='g')
#df_train['counts'].plot(kind='box')

plt.figure();
g = df_train.groupby('hour')
#g['counts'].sum().plot()
#g[df_train.datetime.values].plot()
plt.plot(g['counts'].sum())
plt.grid()
plt.xlabel("Hours");
plt.ylabel("count")
plt.xlim(0,23)
#plt.ylim(0,100)
#plt.title("Average Daily Rental Counts by Hours During Working Day");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/hour-rental-counts1.png")
plt.show()




plt.figure();
plt.plot(df_train['counts'],'r+')
#df_train.counts[df_train.datetime.values].plot()
plt.xlabel("Period 2011-2012");
plt.ylabel("Count")
plt.grid()
#plt.title("Rental Counts");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/rental-counts1.png")
plt.show()


plt.figure();
plt.plot(df_train['casual'])
plt.xlabel("Period 2011-2012");
plt.ylabel("Count")
plt.grid()
#plt.title("Rental Counts");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/CasualA.png")
plt.show()


plt.figure();
plt.plot(df_train['registered'])
plt.xlabel("Period 2011-2012");
plt.ylabel("Count")
plt.grid()
#plt.title("Rental Counts");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/RegistA.png")
plt.show()



"""
plt.figure();
g = df_train.groupby('hour')
#g['counts'].sum().plot()
#g[df_train.datetime.values].plot()
plt.plot(a['count'], label='count')
plt.plot(a['casual'],label='casual')
plt.plot(a['registered'],label='registered')
plt.grid()
plt.xlabel("Hours on working-day");
plt.ylabel("Count");
plt.xlim(0,23)
plt.legend(loc='upper right', numpoints=1)
#plt.title("Average Daily Rental Counts by Hours During Working Day");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/hour_group_all.png")
plt.show()
"""



plt.figure();
D=df_train[0:23] 
plt.plot(D['counts']*8.2, label='count')
plt.plot(D['casual']*8.2,label='casual')
plt.plot(D['registered']*8.2,label='registered')
plt.xlabel("Hours on weekend");
plt.ylabel("Count")
plt.xlim(0,22)
plt.grid()
plt.legend(loc='upper right', numpoints=1)
#plt.title("Average Daily Rental Counts by Hours During Non-Working Day");
plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/hour_group_all_B.png")
plt.show()

'''
plt.figure();
D=df_train[0:120] 
plt.plot(D['counts'])
plt.savefig("monthly-count.png")
plt.xlabel("month");
plt.ylabel("count")
plt.title("Rental Counts for  Month");
plt.show()
'''


plt.figure();
plt.plot(df_train.counts[0:100])
plt.xlabel("Day");
plt.ylabel("Count")
plt.grid()
#plt.title("Rental Counts for Four Days");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/cout_for_2_days.png")
plt.show()

"""
plt.figure();
plt.plot(df_train.counts,'b')
axR = plt.plot(15*df_train['temp'],'r',)
#plt.axis([0, 12000, 0, 1000])
plt.xlabel("Period 2011-2012");
plt.ylabel("count")
plt.ylabel("temperature")
plt.grid()
#plt.title("Rental Count and Temperature");
plt.legend(["Count","Temperature"])
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/count_plus_temp.png")
plt.show()
"""
# Out:
# '\nplt.figure();\nplt.plot(df_train.counts,\'b\')\naxR = plt.plot(15*df_train[\'temp\'],\'r\',)\n#plt.axis([0, 12000, 0, 1000])\nplt.xlabel("Period 2011-2012");\nplt.ylabel("count")\nplt.ylabel("temperature")\nplt.grid()\n#plt.title("Rental Count and Temperature");\nplt.legend(["Count","Temperature"])\n#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/count_plus_temp.png")\nplt.show()\n'

# %%
plt.figure();
g = df_train.groupby('hour')
#g['counts'].sum().plot()
#g[df_train.datetime.values].plot()
plt.plot(g['counts'].sum()/220)
plt.grid()
plt.xlabel("Hours");
plt.ylabel("count")
plt.xlim(0,23)
#plt.ylim(0,100)
#plt.title("Average Daily Rental Counts by Hours During Working Day");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/hour-rental-counts1.png")
plt.show()

# %%
data = [df_train['counts'], df_train['hour'],df_train['season']]
plt.figure();
plt.boxplot(data)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f69d1d330d0>,
#   <matplotlib.lines.Line2D at 0x7f69d1dd35d0>,
#   <matplotlib.lines.Line2D at 0x7f69d2040d50>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f69d1de9390>,
#   <matplotlib.lines.Line2D at 0x7f69d1de9b90>,
#   <matplotlib.lines.Line2D at 0x7f69d1dd3510>,
#   <matplotlib.lines.Line2D at 0x7f69d1dd3250>,
#   <matplotlib.lines.Line2D at 0x7f69d210f950>,
#   <matplotlib.lines.Line2D at 0x7f69d20409d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f69d2118a90>,
#   <matplotlib.lines.Line2D at 0x7f69d2118290>,
#   <matplotlib.lines.Line2D at 0x7f69d2129650>,
#   <matplotlib.lines.Line2D at 0x7f69d211f890>,
#   <matplotlib.lines.Line2D at 0x7f69d21302d0>,
#   <matplotlib.lines.Line2D at 0x7f69d214dc10>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f69d1d33e10>,
#   <matplotlib.lines.Line2D at 0x7f69d2129dd0>,
#   <matplotlib.lines.Line2D at 0x7f69d21306d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f69f6793290>,
#   <matplotlib.lines.Line2D at 0x7f69f67933d0>,
#   <matplotlib.lines.Line2D at 0x7f69d1d50d90>,
#   <matplotlib.lines.Line2D at 0x7f69d1d50b90>,
#   <matplotlib.lines.Line2D at 0x7f69d210f3d0>,
#   <matplotlib.lines.Line2D at 0x7f69d210f0d0>]}

# %% [markdown]
# #Weather, temp, atemp, windspeed, humidity

# %%
plt.figure();
#plt.plot(df_train.counts,'r')
plt.plot(df_train['weather'])
#plt.axis([0, 12000, 0, 1000])
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/count_plus_weather.png")
plt.xlabel("Period 2011-2012");
plt.grid()
#plt.ylabel("count")
plt.title("Rental Count and Weather");
plt.legend(["Count","Weather"])
plt.show()


plt.figure();
plt.plot(df_train['atemp'])
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/temperature.png")
plt.xlabel("Period 2011-2012");
plt.ylabel("Temperature")
plt.grid()
plt.title("Average Daily Rental Counts by Month");
plt.show()


plt.figure();
plt.plot(df_train['humidity'])
#plt.savefig("monthly-rental-counts1.png")
plt.xlabel("Monthely period 2011-2012");
plt.ylabel("count")
plt.grid()
plt.title("Average Daily Rental Counts by Month");
plt.show()


plt.figure();
plt.plot(df_train['windspeed'])
plt.savefig("monthly-rental-counts1.png")
plt.xlabel("Monthely period 2011-2012");
plt.ylabel("count")
plt.grid()
plt.title("Average Daily Rental Counts by Month");
plt.show()

# %%
#for i in range(df_train.day.values=12,df_train.day.values=19):
#    plt.plot(df_train.counts)
#plt.figure();
#df_train[df_train.datetime.values].plot()
#plt.show()

#M=pd.range(df_train.day=12,df_train.day=20)
#plt.plot(M['counts'])

#train$season <- factor(train$season, c(1,2,3,4), ordered=FALSE)
#train$holiday <- factor(train$holiday, c(0,1), ordered=FALSE)
#train$workingday <- factor(train$workingday, c(0,1), ordered=FALSE)
#train$weather <- factor(train$weather, c(4,3,2,1), ordered=TRUE)
#train$datetime <- as.POSIXct(train$datetime, format="%Y-%m-%d %H:%M:%S")
#train$date<-format(train$datetime,"%d-%m-%d")
#train$time<-format(train$datetime,"%H:%M:%S")
#train$hour <- hour(ymd_hms(train$datetime))
#train$week <- week(ymd_hms(train$datetime))
#train$month <- month(ymd_hms(train$datetime))

#train$day <- wday(ymd_hms(train$datetime), label=TRUE)
#train$weekday <- as.factor(weekdays(train$datetime))
#train$weekday <- factor(train$weekday, levels = c("Monday","Tuesday","Wednesday","Thursday","Friday",
 #                                           "Saturday","Sunday")) #order factors

    
    #$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
#s = pd.Series(pd.Categorical(["a","b","c","a"], categories=["c","b","a"]))
#tem = pd.Categorical(["a","b","c","a"], categories=[1,2,3,4], ordered=False)
#tem =df_train.sort('season')
#tem = df_train.sort('season')
     #$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$

# %% [markdown]
# #count', 'temperature'

# %%
from pylab import figure, show, legend, ylabel, xlabel
     

# and the first axes using subplot populated with data 
g=df_train.groupby(['day'])
a= g.counts.mean()

fig1 = figure() 
ax1 = fig1.add_subplot(111)
line1, = ax1.plot(df_train['counts'], 'b+', label="Count")
plt.grid()
ylabel("count")
xlabel("Hours between 2011-2012")
 
# now, the second axes that shares the x-axis with the ax1
ax2 = fig1.add_subplot(111, sharex=ax1, frameon=False)
line2, = ax2.plot(df_train['humidity'],'r,',label="Humidity", linewidth=2)
ax2.yaxis.tick_right()
ax2.yaxis.set_label_position("right")
plt.xlim(0,11000)
ylabel("Humidity")

legend([line1, line2], ['count', 'Humidity'])
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/count_plus_temp_H.png")

show()

# %% [markdown]
# #Plot casual data

# %%
'''plt.figure();
#plt.plot(df_train['counts'])
plt.xlabel("Period 2011-2012");
plt.ylabel("Count")
#plt.title("Rental Counts");
plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/rental_count_actual.png")
plt.show()'''

train_time = pd.TimeSeries(df_train['counts'].values,index=df_train.datetime.values)
train_time = train_time.sort_index()
train_H = train_time.resample('H',how='sum',fill_method='backfill')

plt.figure();
#train_H[df_train.datetime.values].plot()
plt.plot(train_H)
plt.xlabel("Period 2011-2012");   #Period 2011-2012
plt.ylabel("Count")
plt.xlim(0.0,17500)
plt.grid()
#plt.title("Average Daily Rental Counts by Month");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/countW.png")
plt.show()




train_time = pd.TimeSeries(train['registered'].values,index=train.datetime.values)

# Down-sample to calculate per-month means
train_M = train_time.resample('M')
# Add 2011-01-01 and 2012-12-31 23:00 and sort
train_M[pd.datetime(2011,01,01)] = train_M[0]
train_M[pd.datetime(2012,12,31,23)] = train_M[pd.datetime(2012,12,31)]
train_M = train_M.sort_index()

# Up-sample per hour
train_H = train_M.resample('H',fill_method='backfill')

# Extract only test set timestamp values and write to file
#train_H[test.datetime.values].to_csv('month_means.csv')

plt.figure();
train_H[df_train.datetime.values].plot()
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/ave3.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-401bf790bba0> in <module>()
#      25
#      26
# ---> 27 train_time = pd.TimeSeries(train['registered'].values,index=train.datetime.values)
#      28
#      29 # Down-sample to calculate per-month means
#
# NameError: name 'train' is not defined

# %% [markdown]
# ####Now I try to study the seasonality   Fourier Trnasform , Sin and Cos

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib

#First let's open Bicycle train.csv and take a look at it. 
df_train = pd.read_csv('train.csv',parse_dates=["datetime"],header = 0)
df_test = pd.read_csv('test.csv',parse_dates=["datetime"],header = 0)

#set("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images")
#First let's open Bicycle train.csv and take a look at it. 
#df_train = pd.DataFrame.from_csv('/home/aamnah/Google Drive/Project_BikeSharing/code_and_data/Python_Code/train.csv',parse_dates=["datetime"],header = 0)
#In order to see the data we just read in we can use Pandas head command. It allows us to look at any number of lines we need to. I'll go ahead and look at first 100 lines of data. 
df_train.head(1)


#Great! Pandas orginizes everything in a neat table. I wonder what data types we have?
df_train.dtypes


#It would be nice to see how big is our matrix: 
df_train.shape
#So I have 10888 lines and 12 features(columns). I would also like to see if there are any missing values in any of the columns
df_train.count()
#Nice. We don't have anything missing in any column. The only problem for now is the datetime column which is Pandas Series. 
type(df_train.datetime)
#To convert a Series or list-like object of date-like objects e.g. strings I can use the to_datetime function. Here I can use pd.DatetimeIndex to extract month, day and hour out of datetime column. For the day column I would like to show it as day of week, where Monday = 0 and Sunday = 6
df_train['month'] = pd.DatetimeIndex(df_train.datetime).month
df_train['day'] = pd.DatetimeIndex(df_train.datetime).dayofweek
#df_train['days'] = pd.DatetimeIndex(df_train.datetime).date
df_train['hour'] = pd.DatetimeIndex(df_train.datetime).hour
df_train['year'] = pd.DatetimeIndex(df_train.datetime).year
#df_train['weekday'] = pd.DatetimeIndex(df_train.datetime).week
#df_train['Saturday']=0
#df_train['Sunday']=0
#df_train.Saturday[df_train.day==5]=1
#df_train.Sunday[df_train.day==6]=1
#g = df_train.groupby(pd.DatetimeIndex(df_train['day']).normalize())
#g = df_train.groupby(df_train['day'].normalize())

#df_train['cosine']=np.cos(float((df_train.datetime).days)/365.*2*np.pi)
df_train['cosine_year'] = np.cos(df_train['year'].values)+np.sin(df_train['year'].values)
df_train['cosine_month'] = np.cos(df_train['month'].values)+np.sin(df_train['month'].values)
df_train['cosine_day'] = np.cos(df_train['day'].values)+np.sin(df_train['day'].values)
df_train['cosine_hour'] = abs(np.fft.fft(df_train['hour'].values))#np.cos(df_train['hour'].values)+np.sin(df_train['hour'].values)

df_train['cosine'] = abs(np.fft.fft(df_train['month'].values))#+np.sin(df_train['hour'].values)
X =abs(np.fft.fft(df_train['month'].values))# default python: 0....N-1 Foriuer transform
X_sh = np.fft.fftshift(X) 

"""

plt.figure();
g = df_train.groupby('cosine')
#g['counts'].sum().plot()
#g[df_train.datetime.values].plot()
#plt.plot(g['counts'].sum())[1:4]
plt.plot(g['counts'].sum()[1:4])
plt.grid()
plt.xlabel("Years");
plt.ylabel("count")
#plt.title("Average Daily Rental Counts by Hours During Working Day");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/hour-rental-counts1.png")
plt.show()




plt.figure();
g = df_train.groupby('cosine_year')
#g['counts'].sum().plot()
#g[df_train.datetime.values].plot()
plt.plot(g['counts'].sum())
plt.grid()
plt.xlabel("Years");
plt.ylabel("count")
#plt.title("Average Daily Rental Counts by Hours During Working Day");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/hour-rental-counts1.png")
plt.show()

plt.figure();
g = df_train.groupby('cosine_month')
#g['counts'].sum().plot()
#g[df_train.datetime.values].plot()
plt.plot(g['counts'].sum())
plt.grid()
plt.xlabel("Months");
plt.ylabel("count")
#plt.title("Average Daily Rental Counts by Hours During Working Day");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/hour-rental-counts1.png")
plt.show()


plt.figure();
g = df_train.groupby('cosine_day')
#g['counts'].sum().plot()
#g[df_train.datetime.values].plot()
plt.plot(g['counts'].sum())[1:10]
plt.grid()
plt.xlabel("Days");
plt.ylabel("count")
#plt.title("Average Daily Rental Counts by Hours During Working Day");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/hour-rental-counts1.png")
plt.show()
"""
plt.figure();
g = df_train.groupby('cosine_hour')
#g['counts'].sum().plot()
#g[df_train.datetime.values].plot()
plt.plot(df_train.counts[0:120])
#plt.plot(g['counts'].sum())
plt.grid()
plt.xlabel("Hours");
plt.ylabel("count")
#plt.title("Average Daily Rental Counts by Hours During Working Day");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/hour-rental-counts1.png")
plt.show()

# %% [markdown]
# #Try to mearge figure and fix axis

# %%
'''
g = df_train.groupby('day')
g['counts'].sum().plot()

plt.figure();
g = df_train.groupby('Saturday')
g['counts'].sum().plot()

plt.figure();
g = df_train.groupby('Sunday')
g['counts'].sum().plot()
'''

"""
train_time = pd.TimeSeries(df_train['registered'].values,index=df_train.datetime.values)
train_time = train_time.sort_index()
train_H = train_time.resample('H',how='sum',fill_method='backfill')
train_D = train_time.resample('D',how='sum',fill_method='backfill')
train_M = train_time.resample('M',how='sum',fill_method='backfill')

plt.figure();
train_H[df_train.datetime.values].plot()
#plt.plot(train_H)
plt.xlabel("Period 2011-2012");   #Period 2011-2012
plt.ylabel("Count")
#plt.title("Average Daily Rental Counts by Month");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/Average_Daily_Rental_registered_by_Hour.png")
plt.show()


a = g['counts'].sum()/220
b = g['casual'].sum()/220
c = g['registered'].sum()/220


plt.figure();
g = df_train.groupby('hour')
#g['counts'].sum().plot()
#g[df_train.datetime.values].plot()
plt.plot(a['counts'] [49:72], label='count')
plt.plot(b['casual'] [49:72],label='casual')
plt.plot(c['registered'] [49:72],label='registered')
plt.grid()
plt.xlabel("Hours on weekend");
plt.ylabel("Count");
plt.xlim(0,23);
#plt.legend("count","casual","registered")
plt.legend(loc='upper right', numpoints=1)
#plt.title("Average Daily Rental Counts by Hours During Working Day");
plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/month_group_all.png")
plt.show()


train = pd.read_csv('Train_with_Amnah_R.csv',parse_dates=["datetime"],header = 0)

temp = pd.DatetimeIndex(df_train['datetime'])
a = df_train[temp.week == 2]
b = df_train[temp.year == 2012]


testa= a.groupby(['hour'])
testb= b.groupby(['day'])

"""

plt.figure();
g = df_train.groupby('hour')
#g['counts'].sum().plot()
#g[df_train.datetime.values].plot()
plt.plot(a['count'], label='count')
plt.plot(a['casual'],label='casual')
plt.plot(a['registered'],label='registered')
plt.grid()
plt.xlabel("Hours on working-day");
plt.ylabel("Count");
plt.xlim(0,23)
plt.legend(loc='upper right', numpoints=1)
#plt.title("Average Daily Rental Counts by Hours During Working Day");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/hour_group_all.png")
plt.show()



"""

plt.figure();
g = df_train.groupby('hour')
#g['counts'].sum().plot()
#g[df_train.datetime.values].plot()
plt.plot(df_train['counts'].sum()/220, label='count')
plt.plot(df_train['casual'].sum()/220,label='casual')
plt.plot(df_train['registered'].sum()/220,label='registered')
plt.grid()
plt.xlabel("Hours on working-day");
plt.ylabel("Count");
plt.xlim(0,23)
plt.legend(loc='upper right', numpoints=1)
#plt.title("Average Daily Rental Counts by Hours During Working Day");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/hour_group_all.png")
plt.show()




df_train['log-counts'] = df_train['counts'].apply(lambda x: np.log1p(x))
df_train['log-casual'] = df_train['casual'].apply(lambda x: np.log1p(x))
df_train['log-registered'] = df_train['registered'].apply(lambda x: np.log1p(x))

plt.figure();
g = df_train.groupby('hour')
#g['counts'].sum().plot()
#g[df_train.datetime.values].plot()
plt.plot(g['log-counts'].sum())
plt.plot(g['log-casual'].sum())
plt.plot(g['log-registered'].sum())
plt.grid()
plt.xlabel("Hours on week day");
plt.ylabel("count");
plt.legend("count","casual","registered")
#plt.title("Average Daily Rental Counts by Hours During Working Day");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/hour-rental-counts1.png")
plt.show()





#df_train['counts'].boxplot(by='g')
 #bp = df_box.boxplot(by='g')
#df_train['counts'].plot(kind='box')

plt.figure();
g = df_train.groupby('hour')
#g['counts'].sum().plot()
#g[df_train.datetime.values].plot()
plt.plot(g['counts'].sum())
plt.grid()
plt.xlabel("Hours");
plt.ylabel("count")
plt.xlim(0,23)
#plt.title("Average Daily Rental Counts by Hours During Working Day");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/hour-rental-counts1.png")
plt.show()





plt.figure();
g = df_train.groupby('hour')
#g['counts'].sum().plot()
#g[df_train.datetime.values].plot()
plt.plot(g['casual'].sum())
plt.grid()
plt.xlabel("Hours");
plt.ylabel("count")
#plt.title("Average Daily Rental Counts by Hours During Working Day");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/Casual_hour-rental-casual.png")
plt.show()




plt.figure();
g = df_train.groupby('hour')
#g['counts'].sum().plot()
#g[df_train.datetime.values].plot()
plt.plot(g['registered'].sum())
plt.grid()
plt.xlabel("Hours");
plt.ylabel("count")
#plt.title("Average Daily Rental Counts by Hours During Working Day");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/Registered_hour-rental-registered.png")
plt.show()



plt.figure();
plt.plot(df_train['counts'])
#df_train.counts[df_train.datetime.values].plot()
plt.xlabel("Period 2011-2012");
plt.ylabel("Count")
plt.grid()
#plt.title("Rental Counts");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/rental-counts1.png")
plt.show()


plt.figure();
plt.plot(df_train['casual'])
plt.xlabel("Period 2011-2012");
plt.ylabel("Count")
plt.grid()
#plt.title("Rental Counts");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/CasualA.png")
plt.show()


plt.figure();
plt.plot(df_train['registered'])
plt.xlabel("Period 2011-2012");
plt.ylabel("Count")
plt.grid()
#plt.title("Rental Counts");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/RegistA.png")
plt.show()



plt.figure();
D=df_train[0:23] 
plt.plot(D['counts'])
plt.xlabel("Hours on weekend Sunday");
plt.ylabel("Count")
plt.grid()
#plt.title("Average Daily Rental Counts by Hours During Non-Working Day");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/Rental_Counts_for_One_Day.png")
plt.show()



plt.figure();
D=df_train[0:23] 
plt.plot(D['casual'])
plt.xlabel("Hours week end Sunday");
plt.ylabel("Count")
plt.grid()
#plt.title("Average Daily Rental Counts by Hours During Non-Working Day");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/Casual_Day.png")
plt.show()



plt.figure();
D=df_train[0:23] 
plt.plot(D['registered'])
plt.xlabel("Hours weekend Sunday");
plt.ylabel("Count")
plt.grid()
#plt.title("Average Daily Rental Counts by Hours During Non-Working Day");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/registered_Day.png")
plt.show()







plt.figure();
D=df_train[0:120] 
plt.plot(D['counts'])
plt.savefig("monthly-count.png")
plt.xlabel("month");
plt.ylabel("count")
plt.title("Rental Counts for  Month");
plt.show()



plt.figure();
plt.plot(df_train.counts[0:100])
plt.xlabel("Day");
plt.ylabel("Count")
plt.grid()
#plt.title("Rental Counts for Four Days");
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/cout_for_2_days.png")
plt.show()


plt.figure();
plt.plot(df_train.counts,'b')
axR = plt.plot(15*df_train['temp'],'r',)
#plt.axis([0, 12000, 0, 1000])
plt.xlabel("Period 2011-2012");
plt.ylabel("count")
plt.ylabel("temperature")
plt.grid()
#plt.title("Rental Count and Temperature");
plt.legend(["Count","Temperature"])
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/count_plus_temp.png")
plt.show()


plt.figure();
#plt.plot(df_train.counts,'r')
plt.plot(df_train['weather'])
#plt.axis([0, 12000, 0, 1000])
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/count_plus_weather.png")
plt.xlabel("Period 2011-2012");
plt.grid()
#plt.ylabel("count")
plt.title("Rental Count and Weather");
plt.legend(["Count","Weather"])
plt.show()


plt.figure();
plt.plot(df_train['atemp'])
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/temperature.png")
plt.xlabel("Period 2011-2012");
plt.ylabel("Temperature")
plt.grid()
plt.title("Average Daily Rental Counts by Month");
plt.show()


plt.figure();
plt.plot(df_train['humidity'])
#plt.savefig("monthly-rental-counts1.png")
plt.xlabel("Monthely period 2011-2012");
plt.ylabel("count")
plt.grid()
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/humidity.png")
plt.title("Average Daily Rental Counts by Month");
plt.show()


plt.figure();
plt.plot(df_train['windspeed'])
plt.savefig("monthly-rental-counts1.png")
plt.xlabel("Monthely period 2011-2012");
plt.ylabel("count")
plt.grid()
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/windspeed.png")

plt.title("Average Daily Rental Counts by Month");
plt.show()



plt.figure();
g = df_train.groupby('day')
df_train[['counts','casual','registered']][::1].plot()
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/all.png")
  
  
  
  """
# Out:
# '\n\nplt.figure();\ng = df_train.groupby(\'hour\')\n#g[\'counts\'].sum().plot()\n#g[df_train.datetime.values].plot()\nplt.plot(df_train[\'counts\'].sum()/220, label=\'count\')\nplt.plot(df_train[\'casual\'].sum()/220,label=\'casual\')\nplt.plot(df_train[\'registered\'].sum()/220,label=\'registered\')\nplt.grid()\nplt.xlabel("Hours on working-day");\nplt.ylabel("Count");\nplt.xlim(0,23)\nplt.legend(loc=\'upper right\', numpoints=1)\n#plt.title("Average Daily Rental Counts by Hours During Working Day");\n#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/hour_group_all.png")\nplt.show()\n\n\n\n\ndf_train[\'log-counts\'] = df_train[\'counts\'].apply(lambda x: np.log1p(x))\ndf_train[\'log-casual\'] = df_train[\'casual\'].apply(lambda x: np.log1p(x))\ndf_train[\'log-registered\'] = df_train[\'registered\'].apply(lambda x: np.log1p(x))\n\nplt.figure();\ng = df_train.groupby(\'hour\')\n#g[\'counts\'].sum().plot()\n#g[df_train.datetime.values].plot()\nplt.plot(g[\'log-counts\'].sum())\nplt.plot(g[\'log-casual\'].sum())\nplt.plot(g[\'log-registered\'].sum())\nplt.grid()\nplt.xlabel("Hours on week day");\nplt.ylabel("count");\nplt.legend("count","casual","registered")\n#plt.title("Average Daily Rental Counts by Hours During Working Day");\n#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/hour-rental-counts1.png")\nplt.show()\n\n\n\n\n\n#df_train[\'counts\'].boxplot(by=\'g\')\n #bp = df_box.boxplot(by=\'g\')\n#df_train[\'counts\'].plot(kind=\'box\')\n\nplt.figure();\ng = df_train.groupby(\'hour\')\n#g[\'counts\'].sum().plot()\n#g[df_train.datetime.values].plot()\nplt.plot(g[\'counts\'].sum())\nplt.grid()\nplt.xlabel("Hours");\nplt.ylabel("count")\nplt.xlim(0,23)\n#plt.title("Average Daily Rental Counts by Hours During Working Day");\n#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/hour-rental-counts1.png")\nplt.show()\n\n\n\n\n\nplt.figure();\ng = df_train.groupby(\'hour\')\n#g[\'counts\'].sum().plot()\n#g[df_train.datetime.values].plot()\nplt.plot(g[\'casual\'].sum())\nplt.grid()\nplt.xlabel("Hours");\nplt.ylabel("count")\n#plt.title("Average Daily Rental Counts by Hours During Working Day");\n#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/Casual_hour-rental-casual.png")\nplt.show()\n\n\n\n\nplt.figure();\ng = df_train.groupby(\'hour\')\n#g[\'counts\'].sum().plot()\n#g[df_train.datetime.values].plot()\nplt.plot(g[\'registered\'].sum())\nplt.grid()\nplt.xlabel("Hours");\nplt.ylabel("count")\n#plt.title("Average Daily Rental Counts by Hours During Working Day");\n#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/Registered_hour-rental-registered.png")\nplt.show()\n\n\n\nplt.figure();\nplt.plot(df_train[\'counts\'])\n#df_train.counts[df_train.datetime.values].plot()\nplt.xlabel("Period 2011-2012");\nplt.ylabel("Count")\nplt.grid()\n#plt.title("Rental Counts");\n#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/rental-counts1.png")\nplt.show()\n\n\nplt.figure();\nplt.plot(df_train[\'casual\'])\nplt.xlabel("Period 2011-2012");\nplt.ylabel("Count")\nplt.grid()\n#plt.title("Rental Counts");\n#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/CasualA.png")\nplt.show()\n\n\nplt.figure();\nplt.plot(df_train[\'registered\'])\nplt.xlabel("Period 2011-2012");\nplt.ylabel("Count")\nplt.grid()\n#plt.title("Rental Counts");\n#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/RegistA.png")\nplt.show()\n\n\n\nplt.figure();\nD=df_train[0:23] \nplt.plot(D[\'counts\'])\nplt.xlabel("Hours on weekend Sunday");\nplt.ylabel("Count")\nplt.grid()\n#plt.title("Average Daily Rental Counts by Hours During No ...

# %% [markdown]
# #Count

# %% [markdown]
# #Casual

# %% [markdown]
# #Registered

# %%
#from rpy import r
#end_types = set(['M', 'A', 'Q', 'BM', 'BA', 'BQ', 'W'])
#train_H = train_time.resample('H',how=['mean', np.min, np.max])


# Change here  counts , casual , registered
#And the name of files

train_time = pd.TimeSeries(df_train['counts'].values,index=df_train.datetime.values)   # Change here  count , casual , registered
train_time = train_time.sort_index()
train_H = train_time.resample('H',how='sum',fill_method='backfill')

#whole period
plt.figure();
train_H[df_train.datetime.values].plot()
plt.axhline(np.average(df_train['counts']),color='r', linewidth=2)
plt.xlabel("Period 2011-2012");
plt.ylabel("Count")
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/cyc_registered_2011_2012.png")

'''

#p=plt.figure();
#plt.plot(b['counts'])+plt.plot(a['counts'],'r')
#plt.xlabel("Day on 2011");
#plt.ylabel("Count")
#plt.xlim(0,6000)


#Day on 2011 working day
plt.figure();
train_H[df_train.datetime.values][49 : 70 ].plot()+train_H[df_train.datetime.values][71 : 93 ].plot()+train_H[df_train.datetime.values][94 : 116 ].plot()
plt.xlabel("Day on 2011");
plt.ylabel("Count")
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/cyc_casual_day2011.png")



#Day on 2011 weekend
plt.figure();
#train_H[df_train.datetime.values][1 : 24 ].plot()+train_H[df_train.datetime.values][5424 : 5446 ].plot()
plt.plot(train_H[df_train.datetime.values][1 : 24 ],'r', label='1-Jan-2011')+ plt.plot(train_H[df_train.datetime.values][5424 : 5446 ],'b',label='1-Jan-2012')
#plt.xlabel("Day on 2011 and 2012");
plt.ylabel("Count")
plt.xlabel("Hour")
plt.xlim(0,22)
plt.grid()
plt.legend(loc='upper right', numpoints=1)
plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/cyc_counts_day2011_mix.png")
'''

#Day on 2011 weekend
plt.figure();
#train_H[df_train.datetime.values][1 : 24 ].plot()+train_H[df_train.datetime.values][5424 : 5446 ].plot()
plt.plot(train_H[df_train.datetime.values][1 : 380],'r', label='2-Jan-2011 - 16-Jan-2011')+ plt.plot(train_H[df_train.datetime.values][5424 : 5804],'b',label='2-Jan-2012 - 16-Jan-2012')
plt.xlabel("Hour");
plt.ylabel("Count")
plt.xlim(0,380)
plt.grid()
plt.legend(loc='upper right', numpoints=1)
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/cyc_counts_day2011_mix_month.png")

'''

#Day on 2012 weekend
plt.figure();
train_H[df_train.datetime.values][5424 : 5446 ].plot()
plt.xlabel("Day on 2012");
plt.ylabel("Count")
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/cyc_casual_day2012.png")


#week on 2011 
plt.figure();
train_H[df_train.datetime.values][1 : 140 ].plot()#(subplot=True)
plt.xlabel("Week in 2012");
plt.ylabel("Count")
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/cyc_registered_week2011.png")

#Day on 2012
plt.figure();
train_H[df_train.datetime.values][5424 : 5570 ].plot()#(subplot=True)
plt.xlabel("Week in 2012");
plt.ylabel("Count")
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/cyc_registered_week2012.png")


#Half month on 2011
plt.figure();
train_H[df_train.datetime.values][1 : 380].plot()
plt.xlabel("Two weeks in 2011");
plt.ylabel("Count")
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/cyc_registered_long_weeks2011.png")

#Half month on 2012
plt.figure();
train_H[df_train.datetime.values][5424 : 5804].plot()
plt.xlabel("Two weeks in 2012");
plt.ylabel("Count")
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/cyc_registered_long_weeks2012.png")




#plt.figure();
#train_H[df_train.datetime.values][1 : 1356].plot()
#plt.abline()
#r.abline(a=yintercept, b=gradient, col="red")
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/temperature.png")

#df_train.corr    '''
# Out:
# '\n\n#Day on 2012 weekend\nplt.figure();\ntrain_H[df_train.datetime.values][5424 : 5446 ].plot()\nplt.xlabel("Day on 2012");\nplt.ylabel("Count")\n#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/cyc_casual_day2012.png")\n\n\n#week on 2011 \nplt.figure();\ntrain_H[df_train.datetime.values][1 : 140 ].plot()#(subplot=True)\nplt.xlabel("Week in 2012");\nplt.ylabel("Count")\n#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/cyc_registered_week2011.png")\n\n#Day on 2012\nplt.figure();\ntrain_H[df_train.datetime.values][5424 : 5570 ].plot()#(subplot=True)\nplt.xlabel("Week in 2012");\nplt.ylabel("Count")\n#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/cyc_registered_week2012.png")\n\n\n#Half month on 2011\nplt.figure();\ntrain_H[df_train.datetime.values][1 : 380].plot()\nplt.xlabel("Two weeks in 2011");\nplt.ylabel("Count")\n#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/cyc_registered_long_weeks2011.png")\n\n#Half month on 2012\nplt.figure();\ntrain_H[df_train.datetime.values][5424 : 5804].plot()\nplt.xlabel("Two weeks in 2012");\nplt.ylabel("Count")\n#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/cyc_registered_long_weeks2012.png")\n\n\n\n\n#plt.figure();\n#train_H[df_train.datetime.values][1 : 1356].plot()\n#plt.abline()\n#r.abline(a=yintercept, b=gradient, col="red")\n#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/temperature.png")\n\n#df_train.corr    '

# %% [markdown]
# #Take the difference for the two years to see the trends // ???!!!

# %%
temp = pd.DatetimeIndex(df_train['datetime'])
a = df_train[temp.year == 2011]
b = df_train[temp.year == 2012]


testa= a.groupby(['day'])
testb= b.groupby(['day'])


#l=a.counts.astype(int)#[1:140]
#m=b.counts.astype(int)#[1:140]

tmp = []
for ii in range(len(a['counts'])):
    tmp.append(float(b['counts'][ii+5422]-a['counts'][ii]))




plt.plot(tmp,'+')          #Group by day  
plt.axhline(0.0,color='k')
plt.axhline(np.average(tmp),color='r')
plt.xlabel('Hour')
plt.ylabel('Count')
plt.grid()
plt.xlim(0,5500)
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/dif.png")

plt.show()

plt.hist(tmp)
# Out:
# (array([   80.,   176.,   482.,   948.,  1161.,  1091.,   799.,   389.,
#           237.,    59.]),
#  array([-629. , -482.4, -335.8, -189.2,  -42.6,  104. ,  250.6,  397.2,
#          543.8,  690.4,  837. ]),
#  <a list of 10 Patch objects>)

# %%
T.dtype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-caf734764ccb> in <module>()
# ----> 1 T.dtype
#
# NameError: name 'T' is not defined

# %% [markdown]
# #The different between the two years don't touch it

# %%
train_time = pd.TimeSeries(df_train['registered'].values,index=df_train.datetime.values)
train_time = train_time.sort_index()
train_H = train_time.resample('H',how='sum',fill_method='backfill')


temp = pd.DatetimeIndex(df_train['datetime'])
a = df_train[temp.year == 2011]
b = df_train[temp.year == 2012]


testa= a.groupby(['month'])
testb= b.groupby(['month'])


l=a.counts.astype(int)#[1:140]
m=b.counts.astype(int)#[1:140]

tmp = []
for ii in range(len(a['counts'])):
    tmp.append(float(b['counts'][ii+5422]-a['counts'][ii]))

#x = np.arange(0, 140 , 1)
#T=np.arange(0,140,1)
#for i in range(140):
#    T= m[i+5423]-l[i]
    #print T
#t=np.int(T)


plt.plot(tmp,'+')          #Group per day  
plt.axhline(0.0,color='k')
plt.axhline(np.average(tmp),color='r')
plt.xlim(0,5500)
plt.show()

plt.hist(tmp)
# Out:
# (array([   80.,   176.,   482.,   948.,  1161.,  1091.,   799.,   389.,
#           237.,    59.]),
#  array([-629. , -482.4, -335.8, -189.2,  -42.6,  104. ,  250.6,  397.2,
#          543.8,  690.4,  837. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Data Analysis and Chaeck Seasonality

# %%
#-----------------------------------------------Cycle--------------------------
import pandas as pd
from sklearn import ensemble
import datetime
import math
import matplotlib.pyplot as plt


train = pd.read_csv('train.csv',parse_dates=["datetime"],header = 0)
test =  pd.read_csv('test.csv',parse_dates=["datetime"],header = 0)

#Extract date and time
temp=pd.DatetimeIndex(train['datetime'])
day1=datetime.date(2011,01,01)
train['date']=temp.date
train['time']=temp.hour
train['day']=temp.weekday
train['yr']=temp.year
train['month']=temp.month
train['cosine']=[math.cos(float((index-day1).days)/365*2*math.pi) for index in train['date']]
train['season']=train['season'].astype('object')
train['weather']=train['weather'].astype('object')
train['day']=train['day'].astype('object')



temp=pd.DatetimeIndex(test['datetime'])
test['date']=temp.date
test['time']=temp.hour
test['day']=temp.weekday
test['yr']=temp.year
test['month']=temp.month
test['cosine']=[math.cos(float((index-day1).days)/365*2*math.pi) for index in test['date']] #####???!!
test['season']=test['season'].astype('object')
test['weather']=test['weather'].astype('object')
test['day']=test['day'].astype('object')

#plt.plot(train['cosine'],train['counts'])
plt.plot(train['cosine'])
plt.xlabel("Period 2011-2012")
plt.ylabel("Count")
#plt.title("cyclic days")
plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/cyc1.png")
plt.show()

# %% [markdown]
# #Year Scatter Plot

# %%
temp = pd.DatetimeIndex(train['datetime'])
a = train[temp.year == 2011]
b = train[temp.year == 2012]


testa= a.groupby(['month'])
ta=train['counts'].mean()

testb= b.groupby(['month'])
tb=train['counts'].mean()


a=testa.counts.mean()
b=testb.counts.mean()

plt.plot(a,b,'ob')
plt.plot([0,400],[0,400],linewidth=0.3,color='k')
plt.axis('equal')
#plt.xlim(0,1000)
#plt.ylim(0,1000)
plt.grid()
plt.xlabel("Jan-Dec 2011")
plt.ylabel("Jan-Dec 2012")
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/scatter_year.png")


a['counts']= testa.counts.mean()
b['counts']= testb.counts.mean()

plt.figure()
train.plot(['month'],['counts'],kind='scatter')
plt.xlabel("Jan-Dec 2011")
plt.xlim(0,13)
plt.grid()
plt.ylabel("Counts")
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/year_fig.png")


"""
y= df_train.groupby(['year'])
ya= df_train['counts']

plt.figure()
#df_train['counts'].plot(ya)
plt.plot(y['counts'].mean())
plt.xlabel("Jan-Dec 2011")
plt.xlim(0,12)
plt.ylabel("Counts")
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/year_fig.png")
"""


plt.show()

# %%
print train['counts'].mean()
# Out:
# 191.574131913

# %% [markdown]
# #Model Complex Figure

# %%
import numpy as np
import matplotlib.pyplot as plt

# Make some fake data.
a = b = np.arange(0,3, .02)
c = np.exp(a)
d = c[::-1]

# Create plots with pre-defined labels.
p=plt.figure
plt.plot(a, c, 'k', label='Model length',linewidth=1)
plt.plot(a, d, 'k', label='Data length',linewidth=1)
plt.plot(a, c+d, 'b', label='Total message length',linewidth=1)

plt.plot(2.98185, 20.7031, 'b<-')
plt.plot(2.98185, 19.6615, 'b<-')
plt.plot(2.98185, 0.976562, 'b->')

plt.plot(0.02404839, 20.7031, 'b->')
plt.plot(0.02404839, 19.6615, 'b->')
plt.plot(0.02404839, 0.976562, 'b<-')

#plt.plot([1.4879],linewidth=0.3,color='k')
plt.axvline(x=1.4879 ,linewidth=1, color='k', linestyle='dashed')

plt.tick_params('off') 
#set_yaxis().set_visible(False)
plt.yticks([])


plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off') # labels along the bottom edge are off
    
   
#legend = plt.legend(loc='upper center', shadow=True, fontsize='x-large')
# Put a nicer background color on the legend.
#legend.get_frame().set_facecolor('#00FFCC')

plt.text(2.4, 2.4, r'Bias', fontsize=15)
plt.text(2.3, 9.0, r'Variance', fontsize=15)
plt.text(2.2, 18.8, r'Total Error', fontsize=15)
plt.text(1.55, 17.2, r'Optimal model complexity', fontsize=12, verticalalignment='center',rotation='vertical')

plt.xlabel("Model complexity",fontsize=15)
plt.ylabel("Error",fontsize=15)
#plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/complex.png")



plt.show()

# %%
print(__doc__)

import numpy as np
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn import cross_validation

np.random.seed(0)

n_samples = 30
degrees = [1, 4, 15]

true_fun = lambda X: np.cos(1.5 * np.pi * X)
X = np.sort(np.random.rand(n_samples))
y = true_fun(X) + np.random.randn(n_samples) * 0.1

plt.figure(figsize=(14, 5))
for i in range(len(degrees)):
    ax = plt.subplot(1, len(degrees), i + 1)
    plt.setp(ax, xticks=(), yticks=())

    polynomial_features = PolynomialFeatures(degree=degrees[i],
                                             include_bias=False)
    linear_regression = LinearRegression()
    pipeline = Pipeline([("polynomial_features", polynomial_features),
                         ("linear_regression", linear_regression)])
    pipeline.fit(X[:, np.newaxis], y)

    # Evaluate the models using crossvalidation
    scores = cross_validation.cross_val_score(pipeline,
        X[:, np.newaxis], y, scoring="mean_squared_error", cv=10)

    X_test = np.linspace(0, 1, 100)
    plt.plot(X_test, pipeline.predict(X_test[:, np.newaxis]),'r', label="Model")
    plt.plot(X_test, true_fun(X_test),'b', label="True function")
    plt.scatter(X, y, label="Samples")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.xlim((0, 1))
    plt.ylim((-2, 2))
    plt.legend(loc="best")
    plt.title("Polynomial Degree {}".format(
        degrees[i], -scores.mean()))
    #plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/over_fitting.png")

plt.show()
# Out:
# y= df_train.groupby(['year'])
# ya= df_train['counts']
#
# plt.figure()
# #df_train['counts'].plot(ya)
# plt.plot(y['counts'].mean())
# plt.xlabel("Jan-Dec 2011")
# plt.xlim(0,12)
# plt.ylabel("Counts")
# #plt.savefig("/home/aamnah/Google Drive/Project_BikeSharing/research-project-templete-amnah/Template/images/year_fig.png")

# %% [markdown]
# #Seasonality Decompose ????!!     Package not found

# %%
import scikits.statsmodels.api as sm
sm.open_help()


import statsmodels.api as sm

dta = sm.datasets.co2.load_pandas().data
# deal with missing values. see issue
dta.co2.interpolate(inplace=True)

#res = sm.tsa.seasonal_decompose(dta.co2)
res = sm.tsa.seasonal_decompose(df_train.counts)
resplot = res.plot()


res.resid
res.seasonal
res.trend
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-21-1c29a29cae0e> in <module>()
# ----> 1 import scikits.statsmodels.api as sm
#       2 sm.open_help()
#       3
#       4
#       5 import statsmodels.api as sm
#
# ImportError: No module named scikits.statsmodels.api
